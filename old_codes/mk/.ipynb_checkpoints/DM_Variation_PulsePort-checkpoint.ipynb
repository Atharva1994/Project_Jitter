# %%
import numpy as np
import psrchive as psr
import matplotlib.pyplot as plt
import os
import astropy.stats as ast
from astropy.utils import NumpyRNGContext
import scipy.stats as scs
# %matplotlib notebook

# %%
os.chdir('/fred/oz005/users/akulkarn/J0437-4715/J0437-4715_meerkat_19May_22/Processed/DM_measurements')

DM_chi_4p=np.genfromtxt("DM_chi_withk_4pulInt_all.txt")  # data containing "DM DM_err Chi_sqr" as a table obtained using TEMPO2
DM_pptoa_4p=np.genfromtxt("DM_pptoa_4p")  # data containing "DM" as a table obtained from PulsePortraiture

# %%
DM_pptoa_4p.shape
# Out:
# (11000,)

# %%
plt.plot(DM_chi_4p[:,0])
plt.plot(DM_pptoa_4p)
# Out:
# <img src="data:image/png;base64,..." width="639.9999780053498">

# %%
DM_chi_4p=np.delete(DM_chi_4p,[4300,4301,4305,4312,4313,4316,4317,5419,7294],0)
Fig, Axs = plt.subplots()

Axs.hist(DM_chi_4p[:,0],bins=500,range=(2.4, 2.9))
Axs.hist(DM_pptoa_4p,bins=500,range=(2.4, 2.9))
Axs.set_xlabel('DM(cm-3 pc)')
# Out:
# <img src="data:image/png;base64,..." width="639.9999780053498">
# Text(0.5, 0, 'DM(cm-3 pc)')

# %%
os.chdir('/fred/oz005/users/akulkarn/J0437-4715/J0437-4715_meerkat_19May_22/Processed/DM_measurements')

DM_chi_8p=np.genfromtxt("DM_chi_withk_8pulInt_all.txt")  # data containing "DM DM_err Chi_sqr" as a table obtained using TEMPO2
DM_pptoa_8p=np.genfromtxt("DM_pptoa_8p")  # data containing "DM" as a table obtained from PulsePortraiture

# %%
DM_pptoa_8p.shape
# Out:
# (5500,)

# %%
plt.plot(DM_chi_8p[:,0])
plt.plot(DM_pptoa_8p)

# %%
DM_chi_8p=np.delete(DM_chi_8p,[4300,4301,4305,4312,4313,4316,4317,5419,7294],0)
Fig, Axs = plt.subplots()

Axs.hist(DM_chi_8p[:,0],bins=500,range=(2.4, 2.9))
Axs.hist(DM_pptoa_8p,bins=500,range=(2.4, 2.9))
Axs.set_xlabel('DM(cm-3 pc)')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_23333/37801849.py in <module>
# ----> 1 DM_chi_8p=np.delete(DM_chi_8p,[4300,4301,4305,4312,4313,4316,4317,5419,7294],0)
#       2 Fig, Axs = plt.subplots()
#       3
#       4 Axs.hist(DM_chi_8p[:,0],bins=500,range=(2.4, 2.9))
#       5 Axs.hist(DM_pptoa_8p,bins=500,range=(2.4, 2.9))
#
# <__array_function__ internals> in delete(*args, **kwargs)
#
# ~/.conda/envs/py3/lib/python3.8/site-packages/numpy/lib/function_base.py in delete(arr, obj, axis)
#    4550         else:
#    4551             keep = ones(N, dtype=bool)
# -> 4552             keep[obj,] = False
#    4553
#    4554         slobj[axis] = keep
#
# IndexError: index 7294 is out of bounds for axis 0 with size 5500
