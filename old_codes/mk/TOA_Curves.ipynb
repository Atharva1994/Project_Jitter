# %%
import numpy as np
import psrchive as psr
import matplotlib.pyplot as plt
import os
import astropy.stats as ast
from astropy.utils import NumpyRNGContext
import scipy.stats as scs
# %matplotlib notebook

# %%
cwd = os.getcwd()
os.chdir('/fred/oz005/users/akulkarn/J0437-4715/J0437-4715_meerkat_19May_22/Processed/timFiles')

# %%
residuals_16p = np.genfromtxt('PostRes_16pulint_Entire_all.txt')
residuals_16p = residuals_16p.reshape((-1,32))  ## Getting residuals_16p in a matrix [subint,freq]

## Deleting residuals corresponding to bad data 
residuals_16p=np.delete(residuals_16p,[0,1,8,26],1)
residuals_16p=np.delete(residuals_16p,[648,1076,1078,1833],0)

# %%
residuals_16p.shape
# Out:
# (2746, 28)

# %%
plt.plot(residuals_16p[:][:])
#plt.scatter(residuals_16p[:,1],residuals_16p[:,5])
#plt.scatter(np.linspace(1,28,num=28),residuals_16p[1,:])
#plt.scatter(np.linspace(1,28,num=28),residuals_16p[2,:])
#plt.scatter(np.linspace(1,28,num=28),residuals_16p[20,:])
#plt.scatter(np.linspace(1,28,num=28),residuals_16p[200,:])
#for i in range(400):
#    plt.scatter(np.linspace(1,28,num=28),residuals_16p[i,:])
# Out:
# <img src="data:image/png;base64,..." width="639.4757875310647">
# ...

# %%
R_16p_spr=np.ndarray([residuals_16p.shape[1],residuals_16p.shape[1]])
R_16p_spr[:,:]=scs.spearmanr(residuals_16p[:,:],axis=0)[0]

plt.figure()
plt.scatter(np.linspace(1,residuals_16p.shape[1],num=residuals_16p.shape[1]),R_16p_spr[0,:])
# Out:
# <img src="data:image/png;base64,..." width="639.6396001714817">

# %%
plt.figure()
plt.scatter(residuals_16p,np.linspace(1,residuals_16p.shape[0]*residuals_16p.shape[1],num=residuals_16p.shape[0]*residuals_16p.shape[1]))
# Out:
# <img src="data:image/png;base64,..." width="703.6035945359188">

# %%
mean_res16p=np.ndarray(residuals_16p.shape[0])
for i in range(mean_res16p.shape[0]):
    mean_res16p[i]=np.mean(residuals_16p[i])
    
sub_mean_res16p=np.ndarray(residuals_16p.shape)

for i in range(residuals_16p.shape[1]):
    sub_mean_res16p[:,i]=np.subtract(residuals_16p[:,i],mean_res16p)

# %%
plt.figure()
for i in range(4):#sub_mean_res16p.shape[0]):
    plt.plot(np.linspace(1,residuals_16p.shape[1],num=residuals_16p.shape[1]),sub_mean_res16p[i+10])
#plt.scatter(np.linspace(1,32*44,num=32*44),sub_mean_res16p)
# Out:
# <img src="data:image/png;base64,..." width="639.4757875310647">

# %%
plt.figure()
plt.plot(sub_mean_res16p[:][:])
# Out:
# <img src="data:image/png;base64,..." width="639.4757875310647">
# ...

# %%
R_16p_res_spr=np.ndarray([sub_mean_res16p.shape[1],sub_mean_res16p.shape[1]])
R_16p_res_spr[:,:]=scs.spearmanr(sub_mean_res16p[:,:],axis=0)[0]

plt.figure()
plt.scatter(np.linspace(1,sub_mean_res16p.shape[1],num=sub_mean_res16p.shape[1]),R_16p_res_spr[0,:])
# Out:
# <img src="data:image/png;base64,..." width="639.6396001714817">

# %%
plt.figure()
plt.plot(mean_res16p)
# Out:
# <img src="data:image/png;base64,..." width="639.4757875310647">

# %% [markdown]
# ### Checking the mean of residuals with the obtained DM value

# %%
os.chdir('/fred/oz005/users/akulkarn/J0437-4715/J0437-4715_meerkat_19May_22/Processed')

DM_chi_16p=np.genfromtxt("DM_chi_withk_16pulInt_all.txt")  # data containing "DM DM_err Chi_sqr" as a table

DM_chi_16p=np.delete(DM_chi_16p,[648,1076,1078,1833],0)

# %%
DM_chi_16p.shape
# Out:
# (2746, 4)

# %%
plt.figure()
plt.scatter(DM_chi_16p[:,0],mean_res16p)
# Out:
# <img src="data:image/png;base64,..." width="639.4757875310647">

# %% [markdown]
# ## 256pulse Observation

# %%
cwd = os.getcwd()
os.chdir('/fred/oz005/users/akulkarn/J0437-4715/J0437-4715_meerkat_19May_22/Processed/timFiles')

# %%
residuals_256p = np.genfromtxt('PostRes_256pulint_Entire_all.txt')
residuals_256p = residuals_256p.reshape((-1,32))  ## Getting residuals_256p in a matrix [subint,freq]

## Deleting residuals corresponding to bad data 
#residuals_256p=np.delete(residuals_256p,[0,1,8,26],1)
#residuals_256p=np.delete(residuals_256p,[648,1076,1078,1833],0)

# %%
residuals_256p.shape
# Out:
# (176, 32)

# %%
plt.figure()
plt.scatter(np.linspace(1,32*176,num=32*176),residuals_256p)
#plt.scatter(residuals_256p[:,1],residuals_256p[:,5])
#plt.scatter(np.linspace(1,28,num=28),residuals_256p[1,:])
#plt.scatter(np.linspace(1,28,num=28),residuals_256p[2,:])
#plt.scatter(np.linspace(1,28,num=28),residuals_256p[20,:])
#plt.scatter(np.linspace(1,28,num=28),residuals_256p[200,:])
#for i in range(400):
#    plt.scatter(np.linspace(1,28,num=28),residuals_256p[i,:])
# Out:
# <img src="data:image/png;base64,..." width="639.6396313962898">

# %%
cwd = os.getcwd()
os.chdir('/fred/oz005/users/akulkarn/J0437-4715/J0437-4715_meerkat_19May_22/Processed/timFiles')

# %%
residuals_1024p = np.genfromtxt('PostRes_1024pulint_Entire_all.txt')
residuals_1024p = residuals_1024p.reshape((-1,32))  ## Getting residuals_1024p in a matrix [subint,freq]

## Deleting residuals corresponding to bad data 
#residuals_1024p=np.delete(residuals_1024p,[0,1,8,26],1)
#residuals_1024p=np.delete(residuals_1024p,[648,1076,1078,1833],0)

# %%
residuals_1024p.shape
# Out:
# (44, 32)

# %%
plt.figure()
#plt.scatter(np.linspace(1,32*44,num=32*44),residuals_1024p[])
#plt.scatter(residuals_1024p[:,1],residuals_1024p[:,5])
plt.scatter(np.linspace(1,32,num=32),residuals_1024p[1,:])
plt.scatter(np.linspace(1,32,num=32),residuals_1024p[2,:])
plt.scatter(np.linspace(1,32,num=32),residuals_1024p[20,:])
#plt.scatter(np.linspace(1,28,num=28),residuals_1024p[200,:])
#for i in range(400):
#    plt.scatter(np.linspace(1,28,num=28),residuals_1024p[i,:])
# Out:
# <img src="data:image/png;base64,..." width="639.6396313962898">

# %%
mean_res=np.ndarray(residuals_1024p.shape[0])
for i in range(mean_res.shape[0]):
    mean_res[i]=np.mean(residuals_1024p[i])
    
sub_mean_res=np.ndarray(residuals_1024p.shape)

for i in range(residuals_1024p.shape[1]):
    sub_mean_res[:,i]=np.subtract(residuals_1024p[:,i],mean_res)

# %%
plt.figure()
for i in range(sub_mean_res.shape[0]):
    plt.plot(np.linspace(1,32,num=32),sub_mean_res[i])
#plt.scatter(np.linspace(1,32*44,num=32*44),sub_mean_res)
# Out:
# <img src="data:image/png;base64,..." width="639.6396313962898">
