# %%
import numpy as np
import psrchive as psr
import matplotlib.pyplot as plt
import os
import astropy.stats as ast
from astropy.utils import NumpyRNGContext
import scipy.stats as scs
import pandas as pd
# %matplotlib notebook

# %%
cwd = os.getcwd()
os.chdir('/fred/oz005/users/akulkarn/J0437-4715/J0437-4715_UWL_01Aug_22/Processed/phase_shifted/timfiles')

# %%
df = pd.read_csv('PostRes_128pulint_Entire_SelChn_all.txt', delim_whitespace=True)
data=df.to_numpy()
data=data.reshape((-1,35,4))
residuals_32p=data[:,:,2]

# %%
rem_int=[]
for i in range(residuals_32p.shape[0]):
    if np.any([np.absolute(a)>0.0001 for a in residuals_32p[i][:]]):
        rem_int.append(i)
        
print(rem_int)
residuals_32p_Intrmd=np.delete(residuals_32p,rem_int,0)
# Out:
# []

# %%
plt.figure()
plt.plot(residuals_32p)

plt.figure()
plt.plot(residuals_32p_Intrmd)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
channels=data[0,:,0]
#print(channels)
count = 0
for i in range(data.shape[0]):
    if not (data[i,:,0] == channels).all:
        count += 1
print(count)
# Out:
# 0
